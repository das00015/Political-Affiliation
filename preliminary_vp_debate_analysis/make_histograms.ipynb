# %%
import os
import glob
import pandas as pd
import time
import matplotlib.pyplot as plt

# %%
data_path = "/home/srivasta/shared/us_presidential_election_2020/SimpleExtractionFeatures/vp_debate_version2"
os.chdir(data_path)

# %%
#specify datatypes so that datatype guessing isnt done (looks like he has mentioned default returned value as 'none' string everywhere)
dtype={'user_id': object, 'counts':int}
df = pd.read_csv('SED/user_counts.csv',dtype=dtype,lineterminator='\n')

# %%
df.head()
# Out:
#                user_id  counts
# 0             15182798     932
# 1  1282059441962188804     831
# 2  1236723571948486657     762
# 3            553668770     701
# 4  1292117436184104961     695

# %%
# %matplotlib inline

# %%
#plt.rcParams['figure.figsize'] = [30, 20]
plt.rcParams['figure.figsize'] = [30, 10]

# %%
df['counts'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
barplot = df['counts'].value_counts().rename_axis('tweet_frequency').reset_index(name='no_of_people')
barplot.tail(20)
# Out:
#      tweet_frequency  no_of_people
# 360              343             1
# 361              361             1
# 362              279             1
# 363              355             1
# 364              354             1
# 365              351             1
# 366              349             1
# 367              348             1
# 368              345             1
# 369              342             1
# 370              240             1
# 371              341             1
# 372              340             1
# 373              339             1
# 374              338             1
# 375              337             1
# 376              335             1
# 377              333             1
# 378              231             1
# 379              932             1

# %% [raw]
# 1176046 people have tweeted 1 time, 321694 people have tweeted two times..so we can visualize a bar plot; where we can see how many times do people typically tweet ?

# %%
barplot.describe()
# Out:
#        tweet_frequency  no_of_people
# count       380.000000  3.800000e+02
# mean        208.389474  5.347287e+03
# std         146.671229  6.312833e+04
# min           1.000000  1.000000e+00
# 25%          95.750000  2.000000e+00
# 50%         190.500000  1.050000e+01
# 75%         288.500000  1.115000e+02
# max         932.000000  1.176046e+06

# %%
ax = barplot.plot.bar(x='tweet_frequency', y='no_of_people', rot=0)
