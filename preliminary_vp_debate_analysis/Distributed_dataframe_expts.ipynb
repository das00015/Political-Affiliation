# %%
import os
import glob
import pandas as pd
import time

# %%
#data_path = "/home/srivasta/shared/us_presidential_election_2020/SimpleExtractionFeatures/vp_debate_version2"
data_path = "/home/srivasta/shared/us_presidential_election_2020/M3_vp_debate"

# %%
os.chdir(data_path)

# %%
from os import listdir
from os.path import isfile, join

# %%
onlyfiles = [f for f in listdir(data_path) if isfile(join(data_path, f))]
print(onlyfiles)
# Out:
# ['Untitled.ipynb', 'merged_csv.csv']

# %%
##Experiments with original pandas
start = time.time()
df = pd.read_csv ("merged_csv.csv")
end = time.time()
print("Read csv with dask: ",(end-start),"sec")
# Out:
# Read csv with dask:  7.119429111480713 sec

# %%
df.shape
# Out:
# (4464065, 5)

# %%
df.head()
# Out:
#                    UID      screen_name  \
# 0            629751550       mykiwitwit
# 1  1307358119782047745     norma_jean81
# 2  1217552218116775941       lestermoe6
# 3  1207400068510371840  worldpe44972666
# 4             36185294         lrlassen
#
#                                                  age  \
# 0  {'<=18': 0.0297, '19-29': 0.1042, '30-39': 0.3...
# 1  {'<=18': 0.0009, '19-29': 0.0027, '30-39': 0.0...
# 2  {'<=18': 0.0149, '19-29': 0.0455, '30-39': 0.0...
# 3  {'<=18': 0.0829, '19-29': 0.0542, '30-39': 0.2...
# 4  {'<=18': 0.0025, '19-29': 0.0046, '30-39': 0.0...
#
#                                gender                                    org
# 0  {'male': 0.3216, 'female': 0.6784}  {'non-org': 0.9267, 'is-org': 0.0733}
# 1  {'male': 0.0017, 'female': 0.9983}  {'non-org': 0.9996, 'is-org': 0.0004}
# 2  {'male': 0.9932, 'female': 0.0068}  {'non-org': 0.9992, 'is-org': 0.0008}
# 3  {'male': 0.0797, 'female': 0.9203}  {'non-org': 0.9998, 'is-org': 0.0002}
# ...

# %%
from dask import dataframe as dd

# %%
##Experiments with dask ##
start = time.time()
dask_df = dd.read_csv('merged_csv.csv')
end = time.time()
print("Read csv with dask: ",(end-start),"sec")
# Out:
# Read csv with dask:  0.008593559265136719 sec

# %%
###Experiments with modin## -- didnt run 
import os
os.environ["MODIN_ENGINE"] = "dask"  # Modin will use Dask
import modin.pandas as pd

# %%
start = time.time()
from distributed import Client
client = Client()
df2 = pd.read_csv ("merged_csv.csv")
end = time.time()
print("Read csv with modin: ",(end-start),"sec")
# Out:
# ...
# To remove this warning, run the following python code before doing dataframe operations:
#
#     from distributed import Client
#
#     client = Client()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.conda/envs/poldebate/lib/python3.7/site-packages/modin/engines/dask/utils.py in initialize_dask()
#      24     try:
# ---> 25         client = default_client()
#      26     except ValueError:
#
# ~/.conda/envs/poldebate/lib/python3.7/site-packages/distributed/client.py in default_client(c)
#    4593         raise ValueError(
# -> 4594             "No clients found\n"
#    4595             "Start a client and point it to the scheduler address\n"
#
# ValueError: No clients found
# Start a client and point it to the scheduler address
#   from distributed import Client
#   client = Client('ip-addr-of-scheduler:8786')
#
#
# ...
